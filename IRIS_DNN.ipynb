# %% [markdown]
# <a href="https://colab.research.google.com/github/prajaktapawar1234567/Deep-Learning-Assignments/blob/master/IRIS_DNN.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow import keras

# %%
from sklearn.datasets import load_iris
dataset =load_iris()

# %%
df_flower=pd.DataFrame(dataset['data'],columns=dataset['feature_names'])
df_flower.head()
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2

# %%
df_flower['flower_label']=dataset['target']
df_flower.head()
# Out:
#    sepal length (cm)  sepal width (cm)  ...  petal width (cm)  flower_label
# 0                5.1               3.5  ...               0.2             0
# 1                4.9               3.0  ...               0.2             0
# 2                4.7               3.2  ...               0.2             0
# 3                4.6               3.1  ...               0.2             0
# 4                5.0               3.6  ...               0.2             0
#
# [5 rows x 5 columns]

# %%
df_flower['flower_name']=df_flower['flower_label'].replace(to_replace=[0,1,2],value=dataset['target_names'])

# %%
df_flower.head()
# Out:
#    sepal length (cm)  sepal width (cm)  ...  flower_label  flower_name
# 0                5.1               3.5  ...             0       setosa
# 1                4.9               3.0  ...             0       setosa
# 2                4.7               3.2  ...             0       setosa
# 3                4.6               3.1  ...             0       setosa
# 4                5.0               3.6  ...             0       setosa
#
# [5 rows x 6 columns]

# %%
from sklearn.model_selection import train_test_split
X=df_flower.iloc[:,0:4]
Y=df_flower.iloc[:,4:5]
xtrain,xtest,ytrain ,ytest  = train_test_split(X,Y,test_size=0.30,random_state=1)

# %%
from keras.models import Sequential
from  keras.layers import Dense

# %%
model=Sequential()
model.add(Dense(10,input_shape=(4,),activation="relu"))

# %%
#from keras.backend import sparse_categorical_crossentropy
model.compile(
    optimizer="adam",
    loss='sparse_categorical_crossentropy',
    metrics=["accuracy"]

)
model.fit(xtrain,ytrain,epochs=200)
# Out:
# Epoch 1/200
# 4/4 [==============================] - 1s 6ms/step - loss: 1.8419 - accuracy: 0.3429
# Epoch 2/200
# 4/4 [==============================] - 0s 5ms/step - loss: 1.8239 - accuracy: 0.3429
# Epoch 3/200
# 4/4 [==============================] - 0s 6ms/step - loss: 1.8070 - accuracy: 0.3429
# Epoch 4/200
# 4/4 [==============================] - 0s 8ms/step - loss: 1.7895 - accuracy: 0.3429
# Epoch 5/200
# 4/4 [==============================] - 0s 3ms/step - loss: 1.7741 - accuracy: 0.3429
# Epoch 6/200
# 4/4 [==============================] - 0s 3ms/step - loss: 1.7586 - accuracy: 0.3429
# Epoch 7/200
# 4/4 [==============================] - 0s 4ms/step - loss: 1.7432 - accuracy: 0.3429
# Epoch 8/200
# 4/4 [==============================] - 0s 3ms/step - loss: 1.7280 - accuracy: 0.3429
# Epoch 9/200
# 4/4 [==============================] - 0s 5ms/step - loss: 1.7132 - accuracy: 0.3429
# Epoch 10/200
# ...
